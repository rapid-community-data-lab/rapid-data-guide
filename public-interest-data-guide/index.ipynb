# %% [markdown]
# ---
# toc: false
# page-navigation: false
# page-layout: full
# sidebar: false
# ---

# %% [markdown]
# # Welcome to the Public Interest Data Guide
#
# :::: {.content-visible when-profile="dev"}
# ::: {.callout-warning}
# This is a development version of the site and is not intended for public use.
# :::
# ::::

# %% [markdown]
# ::::::{.grid}
# :::::{.card .g-col-6}
# ![](/images/nla.obj-162853701-1.jpg){.card-img-top  fig-alt="Vladimir Petrov attends third hearing of Royal Commission on espionage in Melbourne, 5 July 1954"}
#
# ::::{.card-body}
#
# :::{.card-text}
# <small class="text-body-secondary">Photo credit: [https://nla.gov.au/nla.obj-162853701](https://nla.gov.au/nla.obj-162853701)</small>
# :::
#
# ### Hansard{.card-title}
#
# :::{.card-text}
#
# Explore the record of what was spoken in the Australian parliament.
#
#
# <a href="/hansard/hansard-intro.ipynb" class="btn btn-primary">Get started</a>
# :::
#
# ::::
# :::::
#
# :::::{.card  .g-col-6}
# ![](/images/nla.obj-138263562-1.jpg){.card-img-top  fig-alt="Politicians sitting in a chamber for the opening of Parliament House"}
#
# ::::{.card-body}
#
# :::{.card-text}
# <small class="text-body-secondary">Photo credit: [https://nla.gov.au/nla.obj-138263562](https://nla.gov.au/nla.obj-138263562)</small>
# :::
#
# ### Reviews and inquiries {.card-title}
#
# :::{.card-text}
#
# Explore public submissions to government reviews and inquiries.
#
# <a href="/inquiries/inquiries-intro.ipynb" class="btn btn-primary">Get started</a>
# :::
#
# ::::
# :::::
# ::::::
