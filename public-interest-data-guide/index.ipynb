# %% [markdown]
# ---
# toc: false
# page-navigation: false
# page-layout: full
# sidebar: false
# ---

# %% [markdown]
# # Welcome to the Public Interest Data Guide
#
# :::: {.content-visible when-profile="dev"}
# ::: {.callout-warning}
# This is a development version of the site and is not intended for public use.
# :::
# ::::

# %% [markdown]
# ## Get started
#
# :::::: {.grid}
# ::::: {.card .g-col-6}
# :::: {.card-body}
#
# ### Hansard {.card-title}
#
# ::: {.card-text}
#
# 🗣️ Explore the record of what was spoken in the Australian parliament.
#
# [What is Hansard? →](/hansard/hansard-intro.ipynb)
# :::
# ::::
# :::::
#
# ::::: {.card  .g-col-6}
#
# :::: {.card-body}
#
# ### Reviews and inquiries {.card-title}
#
# ::: {.card-text}
#
# 📚 Explore public submissions to government reviews and inquiries.
#
# [Introduction →](/inquiries/inquiries-intro.ipynb)
# :::
#
# ::::
# :::::
# ::::::

# %% [markdown]
# ## More information
#
# :::::: {.grid}
# ::::: {.card .g-col-6}
# :::: {.card-body}
#
# ### About this site {.card-title}
#
# ::: {.card-text}
#
# [About →](/about.ipynb)
# :::
# ::::
# :::::
#
# ::::: {.card  .g-col-6}
#
# :::: {.card-body}
#
# ### Contributing {.card-title}
#
# ::: {.card-text}
#
# [Contributing →](/contributing/contributing.ipynb)
# :::
#
# ::::
# :::::
# ::::::
