# %% [markdown]
# # Contributing

# %% [markdown]
# ## Jupyter Book
#
# This site is built using [Jupyter Book](https://jupyterbook.org/). Jupyter Book takes a collection of Markdown files and Jupyter notebooks and renders them as a static HTML  site with a book-like structure. The Jupyter notebooks can include code cells that are executed at build time to generate tables, visualisations and other outputs.

# %% [markdown]
# ## Markdown

# %% [markdown]
# ## Front matter

# %% [markdown]
# ## Embedding code

# %% [markdown]
# ## Hints and tips

# %% [markdown]
# ## Style
#
# Follow the *Australian Government Style Manual* in naming government entities:
#
# - [Government terms](https://www.stylemanual.gov.au/grammar-punctuation-and-conventions/names-and-terms/government-terms)
# - [Parliaments and Councils](https://www.stylemanual.gov.au/grammar-punctuation-and-conventions/titles-honours-forms-address/parliaments-and-councils)

# %%
x = "hello"

# %% [markdown]
# The variable is: {eval}`x`
