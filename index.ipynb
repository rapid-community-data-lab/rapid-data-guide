# %% [markdown]
# ---
# site:
#     hide_outline: true
# ---

# %% [markdown]
# # Welcome to the Public Interest Data Guide
#
# :::{warning}
# This is a development version of the site and is not intended for public use.
# :::

# %% [markdown]
# ## Get started
#
# ::::{grid} 1 1 2 2
#
# :::{card}
# :header: Hansard 🗣️
# :link: ./hansard/hansard-intro
# :footer: [What is Hansard? →](hansard/hansard-intro)
# Explore the record of what was spoken in the Australian parliament.
# :::
#
# :::{card}
# :header: Reviews and inquiries 📚
# :link: ./inquiries/inquiries-intro
# :footer: [Introduction →](./inquiries/inquiries-intro)
# Explore public submissions to government reviews and inquiries.
# :::
#
# ::::

# %% [markdown]
# ## More information
#
# ::::{grid} 1 1 2 2
#
# :::{card}
# :header: About
# :link: ./about
# :footer: [About →](./about)
# Learn more about this site.
# :::
#
# :::{card}
# :header: Contributing
# :link: ./contributing
# :footer: [Contributing →](./contributing)
# Learn how to contribute to this site.
# :::
#
# ::::
